# %%
import pandas as pd

File = 'swiggy.csv'

df = pd.read_csv(File)

df.head(5)
# Out:
#     ID         Area       City         Restaurant  Price  Avg ratings  \
# 0  211  Koramangala  Bangalore        Tandoor Hut  300.0          4.4
# 1  221  Koramangala  Bangalore      Tunday Kababi  300.0          4.1
# 2  246    Jogupalya  Bangalore            Kim Lee  650.0          4.4
# 3  248  Indiranagar  Bangalore  New Punjabi Hotel  250.0          3.9
# 4  249  Indiranagar  Bangalore                Nh8  350.0          4.0
#
#    Total ratings                                          Food type  \
# 0            100          Biryani,Chinese,North Indian,South Indian
# 1            100                                   Mughlai,Lucknowi
# 2            100                                            Chinese
# 3            500               North Indian,Punjabi,Tandoor,Chinese
# 4             50  Rajasthani,Gujarati,North Indian,Snacks,Desser...
#
#         Address  Delivery time
# 0     5Th Block             59
# 1     5Th Block             56
# 2   Double Road             50
# ...

# %%
# How many rows?
len(df)
# What columns exist?
df.columns

# Any missing values?
df.isnull().sum()

# Data types correct? (date, numbers)
df.info()

# %%
# Unique Restaurants count by city
unique_restaurants = df.groupby('City')['Restaurant'].nunique().reset_index(name='counts')
unique_restaurants
# Out:
#         City  counts
# 0  Ahmedabad     709
# 1  Bangalore     938
# 2    Chennai    1096
# 3      Delhi     611
# 4  Hyderabad    1030
# 5    Kolkata    1325
# 6     Mumbai    1253
# 7       Pune    1080
# 8      Surat     505

# %%
# Which city has MOST top-rated restaurants
top_rated_restaurent = df[df['Avg ratings'] > 4.5].groupby(['City'])['Restaurant'].nunique().sort_values(ascending=False)
top_rated_restaurent
# Out:
# City
# Kolkata      61
# Chennai      60
# Mumbai       49
# Pune         44
# Bangalore    41
# Ahmedabad    21
# Hyderabad    18
# Delhi        14
# Surat        14
# Name: Restaurant, dtype: int64

# %%
# Avg delivery time per city
df.groupby('City')['Delivery time'].mean()
# Out:
# City
# Ahmedabad    44.709902
# Bangalore    50.529598
# Chennai      58.968354
# Delhi        50.734861
# Hyderabad    49.933023
# Kolkata      67.809807
# Mumbai       48.318716
# Pune         55.854128
# Surat        48.484375
# Name: Delivery time, dtype: float64

# %%
# Top 5 Restaurants by rating

df.sort_values(by='Avg ratings', ascending=False).head(5)
# Out:
#           ID               Area     City          Restaurant  Price  \
# 5424  427280            Chembur   Mumbai     Get In My Belly  500.0
# 5425  427282            Chembur   Mumbai  The Asian Pavilion  200.0
# 5519  431996  Scruz Bandra East   Mumbai         Cafe Kokomo  400.0
# 8571  450543           Perambur  Chennai              Afresh  100.0
# 6297  458258                Nsp    Delhi           Fat Tiger  300.0
#
#       Avg ratings  Total ratings                                 Food type  \
# 5424          5.0             20                                    Indian
# 5425          5.0             20                            Asian  Chinese
# 5519          5.0             50          Beverages,Snacks,Desserts,Bakery
# 8571          5.0             20    Healthy Food,Salads,Desserts,Beverages
# 6297          5.0             20  Pizzas,Chinese,Snacks,Beverages,American
#
#                 Address  Delivery time
# 5424            Chembur             58
# ...

# %%
# Top 5 by popularity
df.sort_values(by='Total ratings', ascending=False).head(5)
# Out:
#           ID         Area       City                     Restaurant  Price  \
# 1819  131870   Kavadiguda  Hyderabad               4M Biryani House  250.0
# 90      4138         Koti  Hyderabad                    Grand Hotel  300.0
# 803    34634  Toli Chowki  Hyderabad  Shah Ghouse Cafe & Restaurant  350.0
# 4069  367769      Chintal  Hyderabad               Lucky Restaurant  300.0
# 95      4320  Narayanguda  Hyderabad                         Mehfil  300.0
#
#       Avg ratings  Total ratings  \
# 1819          4.1          10000
# 90            4.1          10000
# 803           4.0          10000
# 4069          4.0          10000
# 95            3.9          10000
#
#                                               Food type  \
# 1819                       Biryani,North Indian,Chinese
# 90       Biryani,Tandoor,Chinese,Indian,Kebabs,Desserts
# 803    Biryani  North Indian  Chinese  Mughlai  Tandoor
# 4069  Biryani,Tandoor,Chinese,North Indian,Desserts,...
# ...

# %%
# sort by avg rating , total ratings values
best_restaurants = df.sort_values(by=['Avg ratings', 'Total ratings'], ascending=[False, False]).head(5)
best_restaurants
# Out:
#           ID               Area    City               Restaurant  Price  \
# 5519  431996  Scruz Bandra East  Mumbai              Cafe Kokomo  400.0
# 3894  357553        Bandra East  Mumbai  Diamond Market Pizza Jp  600.0
# 5424  427280            Chembur  Mumbai          Get In My Belly  500.0
# 5425  427282            Chembur  Mumbai       The Asian Pavilion  200.0
# 5684  438198            Kothrud    Pune                Papacream  350.0
#
#       Avg ratings  Total ratings                         Food type  \
# 5519          5.0             50  Beverages,Snacks,Desserts,Bakery
# 3894          5.0             20                           Italian
# 5424          5.0             20                            Indian
# 5425          5.0             20                    Asian  Chinese
# 5684          5.0             20                         Ice Cream
#
#                 Address  Delivery time
# 5519  Scruz Bandra East             46
# 3894  Scruz Bandra East             43
# ...

# %%
# Top 5 city by avg rating and total ratings

city_analysis = df.groupby('City').agg({'Avg ratings' : 'mean', 'Total ratings': 'mean'}).reset_index()

city_analysis = city_analysis.sort_values(by=['Avg ratings', 'Total ratings'], ascending=[False , False])
city_analysis.head(5)
# Out:
#         City  Avg ratings  Total ratings
# 2    Chennai     3.776311     161.717902
# 1  Bangalore     3.762896     148.520085
# 4  Hyderabad     3.701395     307.227907
# 5    Kolkata     3.698811     163.298663
# 6     Mumbai     3.599374     118.214565

# %%
# Top Restaurant by City
top_restaurant = df.groupby(['City', 'Restaurant']).agg({'Avg ratings': 'mean', 'Total ratings': 'sum'}).reset_index()
top_restaurant = top_restaurant.sort_values(by=['Avg ratings', 'Total ratings'], ascending=[False , False]).groupby('City').head(1)
top_restaurant
# Out:
#            City                            Restaurant  Avg ratings  \
# 5894     Mumbai                           Cafe Kokomo          5.0
# 922   Bangalore                        Creams & Bites          5.0
# 1670    Chennai                                Afresh          5.0
# 2915      Delhi                             Fat Tiger          5.0
# 4167  Hyderabad  Splurge - Thickshakes And Milkshakes          5.0
# 5023    Kolkata                Keventers Ice Creamery          5.0
# 7650       Pune                             Papacream          5.0
# 419   Ahmedabad                     Natural Ice Cream          4.8
# 8269      Surat                       Kudrati Kahumbo          4.8
#
#       Total ratings
# 5894             50
# 922              20
# 1670             20
# 2915             20
# 4167             20
# 5023             20
# 7650             20
# 419             100
# 8269             50

# %%
# Top 3 restaurants per city
top_3_restaurant_by_city = df.groupby(['City', 'Restaurant']).agg({'Avg ratings': 'mean', 'Total ratings': 'sum'}).reset_index()
top_3_restaurant_by_city = top_3_restaurant_by_city.sort_values(by=['City', 'Avg ratings', 'Total ratings'] , ascending=[True,  False, False]).groupby('City').head(3)
top_3_restaurant_by_city
# Out:
#            City                              Restaurant  Avg ratings  \
# 419   Ahmedabad                       Natural Ice Cream          4.8
# 699   Ahmedabad  Wok On Fire - Indo Chinese - Pan Asian          4.8
# 144   Ahmedabad                     Ching Chong Chinese          4.8
# 922   Bangalore                          Creams & Bites          5.0
# 1589  Bangalore                           Tricky Shakes          5.0
# 990   Bangalore                          Frosty Crumble          4.9
# 1670    Chennai                                  Afresh          5.0
# 1648    Chennai                                    1By2          4.9
# 2276    Chennai                         Milkie Mustache          4.9
# 2915      Delhi                               Fat Tiger          5.0
# 2787      Delhi                         Biryani By Kilo          4.8
# 3149      Delhi                   Pizza Paradise By Vhc          4.8
# 4167  Hyderabad    Splurge - Thickshakes And Milkshakes          5.0
# ...

# %%
# Over Hyped Restaurant by City by popularity
threshold = 2.5
over_hyped = df[df['Avg ratings'] < threshold].groupby(['City', 'Restaurant'])['Total ratings'].sum().reset_index()
over_hyped = over_hyped.sort_values(by='Total ratings',ascending=False).groupby('City').head(1)
over_hyped
# Out:
#         City                    Restaurant  Total ratings
# 2  Hyderabad            The Shawarma Daddy             50
# 0  Ahmedabad      Cia Chinese In Ahmedabad             20
# 3    Kolkata              Diwan Food Court             20
# 4       Pune  Golden Dragon Chinese & Momo             20

# %%
import matplotlib.pyplot as plt


plt.figure(figsize=(10, 5))
bar = plt.bar(unique_restaurants['City'], unique_restaurants['counts'])
plt.title("Unique Restataurants By City")
plt.show()

# %%
top_restaurant['label'] = top_restaurant['City'] + " - " + top_restaurant['Restaurant']

top_restaurant.plot(
    x='label',
    y='Total ratings',
    kind='barh'
)

plt.xticks(rotation=60)
plt.show()

# %%
city_avg_rate_analysis = df.groupby('City').agg({
    'Avg ratings': 'mean'
}).sort_values(by='Avg ratings', ascending=False)

city_avg_rate_analysis.plot(kind='bar')

plt.title('Average Restaurant Ratings by City')
plt.xticks(rotation=45)
plt.show()
